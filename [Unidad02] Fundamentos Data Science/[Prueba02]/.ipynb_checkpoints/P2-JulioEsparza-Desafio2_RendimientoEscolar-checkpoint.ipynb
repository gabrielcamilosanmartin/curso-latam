# %% [markdown]
# # Desafío 2: Rendimiento Escolar
#
#
# Nombre: Julio Esparza H
#
# Profesor: Josué Fredes
#
# Generación: G4
#
#
#
# ## Enunciado
#
# Lo contactan de una escuela Portuguesa para generar un modelo que identifique aquellos alumnos que presentan un bajo desempeño académico, medido en el promedio final del año escolar. Para ello le envían un archivo con registros sociodemográficos y conductuales de los alumnos dos escuelas para perfilar a los estudiantes. De manera adicional la psicopedagoga sugiere inspeccionar una batería de preguntas asociadas a aspectos ambientales del alumno (de famrel a health ) y ver si éstas se pueden abstraer en categorías latentes.
#
# ## Descripción de la base de datos
#
# Para responder esta pregunta deben utilizar el archivo students.csv . Las variables que componen la base se detallan a continuación.
#
# - school : Escuela del estudiante. (binaria: 'GP' - Gabriel Pereira o 'MS' - Mousinho da Silveira)
# - sex : Sexo del estudiante. (binaria: 'F' - Mujer o 'M' - Hombre)
# - age : Edad del estudiante. (numérica: de 15 a 22)
# - address : Ubicación de la casa del estudiante. (binaria: 'U' - urbana o 'R' - rural)
# - famsize : Tamaño de la familia. (binaria: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - Pstatus : Estado cohabitacional de los padres. (binaria: 'T' - cohabitando juntos o 'A' - viviendo separados)
# - Medu : Nivel educacional de la madre. (numérica: 0 - ninguno, 1 - educación básica (4to), 2 - de
# - 5to a 9, 3 - educación media, o 4 - educación superior).
# - Fedu : Nivel educacional del padre. (numérica: 0 - ninguno, 1 - educación básica (4to), 2 - de
# - 5to a 9, 3 - educación media, o 4 - educación superior).
# - Mjob : Ocupación de la madre. (nominal: 'teacher' profesora, 'health' relacionada a salud, 'services' (e.g. administración pública o policía), 'at_home' en casa u 'other' otra).
# - Fjob : Ocupación del padre (nominal: 'teacher' profesor, 'health' relacionado a salud, 'services' (e.g. administración pública o policía), 'at_home' en casa u 'other' otra).
# - reason : Razón para escoger la escuela (nominal: 'home' cercano a casa, 'reputation'
# - reputación de la escuela, 'course' preferencia de cursos u 'other' otra)
# - guardian : Apoderado del estudiante (nominal: 'mother' madre, 'father' padre u 'other' otro)
# - traveltime : Tiempo de viaje entre hogar y colegio. (numeric: 1 - <15 min., 2 - 15 a 30 min., 3 - 30 min. a 1 hora, or 4 - >1 hora).
# - studytime : Horas semanales dedicadas al estudio. (numérica: 1 - <2 horas, 2 - 2 a 5 horas, 3 - 5 a 10 horas, o 4 - >10 horas)
# - failures : Número de clases reprobadas. (numérica: n si 1<=n<3, de lo contrario 4)
# - schoolsup : Apoyo educacional del colegio. (binaria: si o no)
# - famsup : Apoyo educacional familiar. (binaria: si o no)
# - paid : Clases particulares pagadas (matemáticas o portugués) (binaria: si o no)
# - activities : Actividades extracurriculares. (binaria: si o no)nursery : Asistió a guardería infantil. (binaria: si o no)
# - higher : Desea proseguir estudios superiores (binaria: si o no)
# - internet : Acceso a internet desde el hogar (binaria: si o no)
# - romantic : Relación romántica (binaria: si o no)
# - famrel : Calidad de las relaciones familiares. (numérica: de 1 - muy malas a 5 - excelentes)
# - freetime : Tiempo libre fuera del colegio (numérica: de 1 - muy poco a 5 - mucho)
# - goout : Salidas con amigos (numérica: de 1 - muy pocas a 5 - muchas)
# - Dalc : Consumo de alcohol en día de semana (numérica: de 1 - muy bajo a 5 - muy alto)
# - Walc : Consumo de alcohol en fines de semana (numérica: de 1 - muy bajo a 5 - muy alto)
# - health : Estado de salud actual (numérica: from 1 - muy malo to 5 - muy bueno)
# - absences : Cantidad de ausencias escolares (numérica: de 0 a 93)
# - G1 : Notas durante el primer semestre (numérica: de 0 a 20). Este es uno de sus vectores
# - objetivos para el modelo descriptivo.
# - G2 : Notas durante el segundo semestre (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el modelo descriptivo.
# - G3 : Promedio final (numérica: de 0 a 20). Este es uno de sus vectores objetivos para el modelo descriptivo y el vector a predecir en el modelo predictivo.

# %% [markdown]
# ## Preliminares
#
# 1.- Descripción del problema.
#
# 2.- Objetivos.
#
# 3.- Implementación de solución: Criterios de optimización y métricas de desempeño.

# %% [raw]
# 1.- Descripción del problema.
#
# Problema de Regresión, ya que debemos predecir comportamiento de variables continuas 'G1','G2' y 'G3' a partir de variables asociadas.
#
# 2.- Objetivos
#
#     - Objetivo General
#
#         a) Predecir comportamiento de variables 'G3' y modelos saturados de 'G1', 'G2' y 'G3,  a través de datos pertenecientes a student.csv.
#
#     - Objetivos Específicos
#
#         a) Uniformar datos para visualización de archivo .csv dentro de ambiente python.
#         b) Transformar valores nan acorde a buenas prácticas.
#         c) Transformar variables binarias y nominales.
#         d) Evaluar variables relevantes a usar para modelación y predictibilidad de variables.
#         d) Establecer metricas de evaluación para mejora del modelo.
#         e) Definir modelo con mejor predictibilidad y establecer como la mejor solución posible.
#
# 3.- Implementación de solución: Criterios de optimización y métricas de desempeño.
#
#
# Lo primero a realizar es cambiar la forma de expresar información de base de datos. Para esto, se cambiará toda la información binaria y nominal según se indica en enunciado. Junto con esto, se utilizará función para que python reconozca valores NaN de base de datos a través de función desarrollada define_nan.
#
# Posterior a  finalizar mejoras en preprocesamiento, se determinarán las variables a seleccionar para conformar modelo saturado y predictivo. Esta selección se realizará en base a criterios de correlación y minimización de errores. Las principales metricas de evaluación serán R*2 (OLS).

# %% [markdown]
# ## Aspectos Computacionales
#
# 1.- Librerías y módulos a implementar.
#
# 2.- Funciones generadas y su objetivo.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math


import seaborn as sns
# scipy stats para simular
import scipy.stats as stats
# statsmodels para modelación
import statsmodels.api as sm
import statsmodels.formula.api as smf
import missingno as msgn

plt.style.use('seaborn')

import warnings
warnings.filterwarnings("ignore")

NA = float('nan')

def inspeccion_valores(df):
    NA = float('nan')
    for i in df:
        if len(df[i].value_counts()) > 2:
            print(df[i].describe(), "\n")
        else:
            print(df[i].value_counts('%'), "\n")
    return

def define_nan(df):
    for i in df.columns:
        for j in range(df.shape[0]):
            if df[i][j] == 'NaN':
                df[i][j].replace(['NaN'],[NA])
    return

def count_nan(df,var):
    count = 0
    NA = float('nan')
    for i in range(df.shape[0]):
        if df[var][i] == NA:
            count += 1
    return count

def inspeccion_visual(df):
    sns.set(style='whitegrid', rc={"grid.linewidth": 1.1})
    sns.set_context("paper", font_scale=2)  
    for n, i in enumerate(df,1):
        plt.figure(figsize=(10,100))
        plt.subplot(df.shape[1], 1, n)
        if len(df[i].value_counts()) > 2:
            sns.distplot(df[i])
            plt.title(i)
            plt.xlabel("")        
        else:
            sns.countplot(y=df[i])
            plt.title(i)
            plt.xlabel("")
            plt.tight_layout()
    return

# %%
df = pd.read_csv('students.csv')

# %% [markdown]
# ## Inspección Inicial

# %%
# Se realiza primera inspección para revisar status actual de variables.
inspeccion_valores(df)
# Out:
# GP    0.884615
# MS    0.115385
# Name: school, dtype: float64
#
# F    0.52551
# M    0.47449
# Name: sex, dtype: float64
#
# count    391.000000
# mean      16.698210
# std        1.279412
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64
#
# U    0.776081
# R    0.223919
# Name: address, dtype: float64
#
# GT3    0.710997
# LE3    0.289003
# Name: famsize, dtype: float64
#
# T    0.897172
# A    0.102828
# Name: Pstatus, dtype: float64
#
# count    392.000000
# mean       2.742347
# std        1.095185
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000
# Name: Medu, dtype: float64
#
# count    390.000000
# mean       2.525641
# std        1.088906
# min        0.000000
# 25%        2.000000
# 50%        2.500000
# 75%        3.000000
# max        4.000000
# Name: Fedu, dtype: float64
#
# count       389
# unique        5
# ...

# %% [markdown]
# ## Preprocesamiento de Variables

# %%
#A partir de primera inspección se realiza preprocesamiento para binarizar o elaborar variables dummy según se requiera.
# Para esto se utiliza nuevo data frame df_1.

df_1 = df.dropna()


df_1['Mjob-teacher_dummy'] = np.where(df_1['Mjob'] == 'teacher',1,0)
df_1['Mjob-health_dummy'] = np.where(df_1['Mjob'] == 'health',1,0)
df_1['Mjob-services_dummy'] = np.where(df_1['Mjob'] == 'services',1,0)
df_1['Mjob-athome_dummy'] = np.where(df_1['Mjob'] == 'at_home',1,0)
df_1['Mjob-other_dummy'] = np.where(df_1['Mjob'] == 'other',1,0)

df_1['Fjob-teacher_dummy'] = np.where(df_1['Fjob'] == 'teacher',1,0)
df_1['Fjob-health_dummy'] = np.where(df_1['Fjob'] == 'health',1,0)
df_1['Fjob-services_dummy'] = np.where(df_1['Fjob'] == 'services',1,0)
df_1['Fjob-athome_dummy'] = np.where(df_1['Fjob'] == 'at_home',1,0)
df_1['Fjob-other_dummy'] = np.where(df_1['Fjob'] == 'other',1,0)

df_1['reason-home_dummy'] = np.where(df_1['reason'] == 'home',1,0)
df_1['reason-reputation_dummy'] = np.where(df_1['reason'] == 'reputation',1,0)
df_1['reason-course_dummy'] = np.where(df_1['reason'] == 'course',1,0)
df_1['reason-other_dummy'] = np.where(df_1['reason'] == 'other',1,0)

df_1['guardian-mother_dummy'] = np.where(df_1['guardian'] == 'mother',1,0)
df_1['guardian-father_dummy'] = np.where(df_1['guardian'] == 'father',1,0)
df_1['guardian-other_dummy'] = np.where(df_1['guardian'] == 'other',1,0)

df_1['school'] = np.where(df_1['school'] == 'GP',0,1)
df_1['sex'] = np.where(df_1['sex'] == 'M',1,0)
df_1['address'] = np.where(df_1['address'] == 'R',1,0)
df_1['famsize'] = np.where(df_1['famsize'] == 'LE3',1,0)
df_1['Pstatus'] = np.where(df_1['Pstatus'] == 'A',1,0)
df_1['schoolsup'] = np.where(df_1['schoolsup'] == 'yes',1,0)
df_1['famsup'] = np.where(df_1['famsup'] == 'no',1,0)
df_1['paid'] = np.where(df_1['paid'] == 'yes',1,0)
df_1['activities'] = np.where(df_1['activities'] == 'no',1,0)
df_1['nursery'] = np.where(df_1['nursery'] == 'no',1,0)
df_1['higher'] = np.where(df_1['higher'] == 'no',1,0)
df_1['internet'] = np.where(df_1['internet'] == 'no',1,0)
df_1['romantic'] = np.where(df_1['romantic'] == 'yes',1,0)

# %%
# La inspección de valores NaN de data frame inicial se muestra en sgte gráfico.
define_nan(df)
msgn.matrix(df)

# %%
for i in range(df.shape[1]):
    print(df.columns[i], ':', round(100 * df[df.columns[i]].isnull().sum() / df.shape[0], 2), '% de datos perdidos')
# Out:
# school : 1.27 % de datos perdidos
# sex : 0.76 % de datos perdidos
# age : 1.01 % de datos perdidos
# address : 0.51 % de datos perdidos
# famsize : 1.01 % de datos perdidos
# Pstatus : 1.52 % de datos perdidos
# Medu : 0.76 % de datos perdidos
# Fedu : 1.27 % de datos perdidos
# Mjob : 1.52 % de datos perdidos
# Fjob : 0.0 % de datos perdidos
# reason : 1.01 % de datos perdidos
# guardian : 1.01 % de datos perdidos
# traveltime : 0.76 % de datos perdidos
# studytime : 1.27 % de datos perdidos
# failures : 1.27 % de datos perdidos
# schoolsup : 2.03 % de datos perdidos
# famsup : 1.27 % de datos perdidos
# paid : 0.25 % de datos perdidos
# activities : 1.27 % de datos perdidos
# nursery : 1.52 % de datos perdidos
# higher : 1.52 % de datos perdidos
# internet : 0.76 % de datos perdidos
# romantic : 0.51 % de datos perdidos
# famrel : 1.27 % de datos perdidos
# freetime : 0.51 % de datos perdidos
# goout : 1.27 % de datos perdidos
# Dalc : 0.76 % de datos perdidos
# ...

# %% [markdown]
# La mayor cantidad de datos perdidos se encuentran en las siguientes variables:
#
#     1,52% ---> Pstatus,Mjob,nursery,higher
#     1,27% ---> school,studytime,failures,famsup,activities,famrel,goout,Walc

# %%
# Posterior a preprocesamiento, el data frame df_1 no muestra NaN dentro de sus valores.
msgn.matrix(df_1)

# %%
# Una aproximación a df_1 se muestra a continuación.
print("La base de datos tiene ", df_1.shape[0], "observaciones y ", df_1.shape[1], " columnas")
print("Las variables de la base de datos son ", df_1.columns)
# Out:
# La base de datos tiene  326 observaciones y  50  columnas
# Las variables de la base de datos son  Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'Mjob-teacher_dummy',
#        'Mjob-health_dummy', 'Mjob-services_dummy', 'Mjob-athome_dummy',
#        'Mjob-other_dummy', 'Fjob-teacher_dummy', 'Fjob-health_dummy',
#        'Fjob-services_dummy', 'Fjob-athome_dummy', 'Fjob-other_dummy',
#        'reason-home_dummy', 'reason-reputation_dummy', 'reason-course_dummy',
#        'reason-other_dummy', 'guardian-mother_dummy', 'guardian-father_dummy',
#        'guardian-other_dummy'],
#       dtype='object')

# %%
# Al generar variables Dummy, se deben eliminar variables nominales. Para esto, se genera nuevo data frame (df_2) que permite
# mantener guardar en df_1 registro de avances. A partir de esto, se realiza inspección de df_2.
df_2 = df_1.drop(['Mjob','Fjob','reason','guardian'],axis=1)
print("La base de datos tiene ", df_2.shape[0], "observaciones y ", df_2.shape[1], " columnas")
print("Las variables de la base de datos son ", df_2.columns)
inspeccion_valores(df_2)
# Out:
# La base de datos tiene  284 observaciones y  46  columnas
# Las variables de la base de datos son  Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'Mjob-teacher_dummy', 'Mjob-health_dummy', 'Mjob-services_dummy',
#        'Mjob-athome_dummy', 'Mjob-other_dummy', 'Fjob-teacher_dummy',
#        'Fjob-health_dummy', 'Fjob-services_dummy', 'Fjob-athome_dummy',
#        'Fjob-other_dummy', 'reason-home_dummy', 'reason-reputation_dummy',
#        'reason-course_dummy', 'reason-other_dummy', 'guardian-mother_dummy',
#        'guardian-father_dummy', 'guardian-other_dummy'],
#       dtype='object')
# 0    0.869718
# 1    0.130282
# Name: school, dtype: float64
#
# 0    0.517606
# 1    0.482394
# ...

# %%
# Con la inspección inicial resuelta, pasamos a inspección visual a través de gráficos, lo que corrobora correcto
# preprocesamiento de variables.

sns.set(style='whitegrid', rc={"grid.linewidth": 1.1})
sns.set_context("paper", font_scale=2)  
for n, i in enumerate(df_2,1):
        plt.figure(figsize=(10,100))
        plt.subplot(46, 1, n)
        if len(df_2[i].value_counts()) > 2:
            sns.distplot(df_2[i])
            plt.title(i)
            plt.xlabel("")        
        else:
            sns.countplot(y=df_2[i])
            plt.title(i)
            plt.xlabel("")
            plt.tight_layout()

# %%
matriz_correlacion = df_2.corr()
plt.rcParams["figure.figsize"] = (40, 40)
sns.set(style='whitegrid', rc={"grid.linewidth": 1.1})
sns.set_context("paper", font_scale=1.5)  
sns.heatmap(matriz_correlacion, cmap = 'Blues', annot = True)

# %% [markdown]
# ## Descripción
#
# 1.- Análisis descriptivo según tipo de variables (enfoque estadístico y computacional).
#
# Considerar medidas univariadas/frecuencias, datos perdidos y gráficos distributivos sobre las variables a analizar. Detallar estrategia de preprocesamiento (datos perdidos y redecodificaciones)

# %% [markdown]
# De todo el desarrollo anterior y con el criterio de correlación de al menos 2 de 3 superior a +/- 0.1, es posible afirmar que existe evidencia de correlación entre las siguientes variables:
#
#     G1,G2,G3 con goout
#     G1,G2,G3 con higher
#     G1,G2,G3 con failures
#     G1,G2,G3 con Medu
#     G1,G2,G3 con Fedu
#     G1,G2,G3 con studytime
#     G1,G2,G3 con schoolsup
#     G1,G2,G3 con famsup
#     G1,G2,G3 con Walc
#     G1,G2,G3 con health
#     G1,G2,G3 con Mjob-health_dummy
#     G1,G2,G3 con Mjob-athome_dummy
#     G1,G2,G3 con Mjob-other_dummy
#     G1,G2,G3 con reason-course_dummy
#
#
# Las variables 'higher,studytime,failures,famsup,Walc' se encuentran entre las que poseen una mayor perdida de datos nulos, por lo que existe un sesgo asociado al comportamiento de estas variables que podría potenciar o reducir correlación con variables G1,G2 y G3. En función a esto, y con un criterio de correlación de alguna variable superior a +/- 0.1, el modelo debe además considerar las siguientes correlaciones:
#
#     G1,G2,G3 con sex
#     G1,G2,G3 con address
#     G1,G2,G3 con traveltime
#     G1,G2,G3 con romantic
#     G1,G2,G3 con Fjob-teacher_dummy
#     G1,G2,G3 con Fjob-other_dummy
#     G1,G2,G3 con reason-reputation_dummy
#     G1,G2,G3 con guardian-other_dummy
#
# Las restantes variables deben ser desechadas.

# %% [markdown]
# ## Modelación Descriptiva
#
# 1.- Principales determinantes del objeto de estudio.
#
# Tip: Bases para construír o depurar el modelo predictivo.

# %% [markdown]
# ## Modelación Predictiva
#
# 1.- Implementación de solución analítica que aumente métricas de desempeño.
#
# Tip: Al menos 3 modelos predictivos y reportar principales métricas. Incluir reseña que justifique el diseño.
